# %%
import os
import json
import random
from google.colab import drive

# %% [markdown]
# ### Dividing data into train test and val

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Testing**

# %%
# %cd /content/drive/Othercomputers/PFE/PFE 2023/data/Video_Dataset
# %ls
# Out:
# /content/drive/Othercomputers/PFE/PFE 2023/data/Video_Dataset
# bad_back_round/  bad_head/         bad_innner_thigh/  bad_toe/  Readme.md
# bad_back_warp/   bad_inner_thigh/  bad_shallow/       good/

# %% [markdown]
# **Setup PATHS**

# %% [markdown]
# ## Data loading

# %%
# Define Path to the Dataset folder
BASE_PATH = '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1'
SUB_CLASSES = os.listdir(BASE_PATH)
print(SUB_CLASSES)
# Out:
# ['bad_head', 'good', 'bad_inner_thigh', 'bad_shallow', 'bad_back_round', 'bad_back_warp', 'bad_toe']

# %%
data = {}
for label, folder_name in enumerate(SUB_CLASSES):
    folder = os.path.join(BASE_PATH, folder_name)
    files = os.listdir(folder)
    file_paths = [os.path.join(folder, file) for file in files if file.endswith(".json")]
    data[label] = {"file_paths":file_paths}
print(data)
# Out:
# {0: {'file_paths': ['/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000023.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000024.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000025.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000026.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000027.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000028.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000032.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000033.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000034.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000035.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000036.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000037.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000038.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000039.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000131.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000132.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000133.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000134.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000135.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000136.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000137.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000138.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000034.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000035.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000036.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000037.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000038.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000039.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000040.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000041.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000136.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000137.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000138.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000139.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_0001 ...

# %%
print(data.keys())
print(data.values())
# Out:
# dict_keys([0, 1, 2, 3, 4, 5, 6])
# dict_values([{'file_paths': ['/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000023.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000024.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000025.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000026.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000027.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0918_squat_000028.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000032.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000033.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000034.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000035.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000036.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000037.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000038.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000039.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000131.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000132.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000133.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000134.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000135.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000136.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000137.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0922_squat_000138.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000034.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000035.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000036.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000037.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000038.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000039.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000040.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000041.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000136.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000137.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000138.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000139.json', '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_s ...

# %%
def create_train_val_test_data(folders_dict, train_pct, val_pct):
    assert train_pct +val_pct <= 1.0, "Sum of train and val percentages should not exceed 1.0"

    train_data = []
    val_data = []
    test_data = []

    for label, folder in enumerate(SUB_CLASSES):
        print(folder)
        file_paths = folders_dict[label]["file_paths"]
        random.shuffle(file_paths)
        num_files = len(file_paths)

        train_end = int(num_files * train_pct)
        val_end = int(num_files * (train_pct + val_pct))

        train_files = file_paths[:train_end]
        val_files = file_paths[train_end:val_end]
        test_files = file_paths[val_end:]

        for file_path in train_files:
            train_data.append({"label": label, "file_path": file_path})

        for file_path in val_files:
            val_data.append({"label": label, "file_path": file_path})

        for file_path in test_files:
            test_data.append({"label": label, "file_path": file_path})

    random.shuffle(train_data)
    random.shuffle(val_data)
    random.shuffle(test_data)

    return  train_data,  val_data,  test_data

# %%
train_frac = 0.7
val_frac = 0.15
test_frac = 0.15

train_data, val_data, test_data = create_train_val_test_data(data, train_frac, val_frac)
print(len(train_data))
print(train_data)

print(len(val_data))
print(val_data)
print(len(test_data))
print(test_data)
# Out:
# bad_head
# good
# bad_inner_thigh
# bad_shallow
# bad_back_round
# bad_back_warp
# bad_toe
# 1343
# [{'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1003_squat_000115.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/0918_squat_000041.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1022_squat_000200.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1025_squat_000019.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1022_squat_000145.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1022_squat_000048.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1018_squat_000147.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1106_squat_000031.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1103_squat_000114.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1015_squat_000136.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/0922_squat_000191.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/1009_squat_000014.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/1029_squat_000153.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1106_squat_000048.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/0918_squat_000049.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/0926_squat_000164.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/0922_squat_000066.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1022_squat_000104.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1029_squat_000003.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1108_squat_000136.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1106_squat_000127.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1018_squat_000243.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/0922_squat_000077.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/0928_squat_000015.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1025_squat_000035.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/bad_squat_squat_000006.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1015_squat_000063.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_t ...
# 291
# [{'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1009_squat_000060.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/0928_squat_000006.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1015_squat_000274.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1009_squat_000147.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/0922_squat_000169.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1025_squat_000139.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1106_squat_000100.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1022_squat_000032.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1103_squat_000101.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000037.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1029_squat_000141.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1108_squat_000002.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1022_squat_000003.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1108_squat_000135.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/clean_squat_squat_000016.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/bad_squat_squat_bar_000011.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1025_squat_000154.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/1009_squat_000114.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1018_squat_000035.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/0922_squat_000019.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1108_squat_000045.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/bad_squat_squat_000086.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1022_squat_000232.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1015_squat_000219.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1009_squat_000050.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/0922_squat_000126.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1022_squat_000217.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/1106_squat_000016.json'}, { ...
# 291
# [{'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/0922_squat_000062.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1108_squat_000009.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/0926_squat_000143.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1022_squat_000136.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1009_squat_000156.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1108_squat_000139.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1108_squat_000129.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1018_squat_000031.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/bad_squat_squat_bar_000022.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1009_squat_000043.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1015_squat_000148.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1018_squat_000250.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1025_squat_000148.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1003_squat_000140.json'}, {'label': 6, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_toe/1106_squat_000022.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/bad_squat_squat_000032.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1025_squat_000231.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/bad_squat_squat_bar_000017.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1018_squat_000207.json'}, {'label': 2, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_inner_thigh/1015_squat_000156.json'}, {'label': 5, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_warp/1018_squat_000039.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1015_squat_000072.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1025_squat_000104.json'}, {'label': 1, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/good/1029_squat_000004.json'}, {'label': 0, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_head/1003_squat_000108.json'}, {'label': 4, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_back_round/1003_squat_000155.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_Dataset_V1/bad_shallow/1018_squat_000121.json'}, {'label': 3, 'file_path': '/content/drive/Othercomputers/PFE/PFE 2023/data/Processed/Keypoints_D ...

# %%
# Save train data
train_file_path = os.path.join(BASE_PATH, "train.json")
with open(train_file_path, 'w') as f:
    json.dump(train_data, f)

# Save test data
test_file_path = os.path.join(BASE_PATH, "test.json")
with open(test_file_path, 'w') as f:
    json.dump(test_data, f)

# Save validation data
val_file_path = os.path.join(BASE_PATH, "val.json")
with open(val_file_path, 'w') as f:
    json.dump(val_data, f)
